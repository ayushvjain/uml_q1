# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'train.csv' 
data = pd.read_csv(file_path)

data.head()
# Out:
#   Stock code    Z-SCORE  Share pledge ratio of controlling shareholders  \
# 0     X00001   2.420039                                        0.152395
# 1     X00002   3.844693                                        0.608351
# 2     X00003   4.975553                                        0.499388
# 3     X00004   4.088897                                        0.000000
# 4     X00005  14.464241                                        0.332566
#
#    Pledge ratio of limited sale shares  Pledge ratio of unlimited shares  \
# 0                             0.000000                          0.126366
# 1                             0.014874                          0.159443
# 2                             0.000000                          0.153660
# 3                             0.000000                          0.001285
# 4                             0.232977                          0.014730
#
#    Stock Volatility    P/E ratio  P/B ratio  \
# 0         49.318786  31.40618754   3.658663
# 1         48.390237  30.42292058   5.460896
# 2         46.639579   106.732585   3.636306
# 3         31.025124  12.81982971   3.392250
# 4         41.572718   94.0221809  65.671415
#
#    Stock price rise and fall in the last year  Annual turnover rate  ...  \
# 0                                   -0.366077              1.420614  ...
# 1                                   -0.133857              2.676361  ...
# 2                                   -0.304963              5.589544  ...
# 3                                    0.906496              2.538287  ...
# 4                                    0.986821              3.692384  ...
#
#    Debt financing costs  Enterprise age  Goodwill impairment ratio  \
# 0             -0.020707       11.258333                   0.000000
# 1              0.026496        9.166667                  -0.000210
# 2              0.018959       10.175000                  -0.000052
# 3             -0.001030       16.494444                  -0.000043
# 4              0.042445        9.391667                   0.000000
#
#    Asset quality index  SG&A Expense  Number of key audit matters  \
# 0             1.212208      1.158201                            1
# 1             1.058507      1.021779                            1
# 2             1.138692      1.260414                            2
# 3             0.929914      0.856676                            2
# 4             0.524995      0.981006                            1
#
#    Number of research institutions concerned  \
# 0                                   3.688879
# 1                                   3.496508
# 2                                   3.784190
# 3                                   3.663562
# 4                                   3.583519
#
#    Number of research reports (+1 LN)  Financial cycle m2/gdp  IsDefault
# 0                            5.505332                0.028941          0
# 1                            5.332719               -0.059096          0
# 2                            5.318120               -0.067378          0
# 3                            5.252273               -0.064161          0
# 4                            5.135798                0.048155          0
#
# [5 rows x 62 columns]

# %%
selected_columns = [
    'Z-SCORE',
    'Asset liability ratio',
    'Current ratio',
    'Cash ratio',
    'EBITDA/interest bearing debt',
    'ROA',
    'ROE',
    'Gross profit margin on sales',
    'Net business cycle (days)',
    'Turnover rate of accounts receivable (Times)',
    'Inventory turnover rate (Times)',
    'Stock Volatility',
    'Debt financing costs',
    'Share pledge ratio of controlling shareholders',
    'P/E ratio',
    'P/B ratio',
    'Stock price rise and fall in the last year',
    'Company nature (state owned assets 0, others 1)',
]

data[selected_columns] = data[selected_columns].apply(pd.to_numeric, errors='coerce')
cleaned_data = data[selected_columns].dropna()

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(cleaned_data)

pca = PCA(n_components=0.95)
pca_data = pca.fit_transform(scaled_data)

print(f"Number of components retained: {pca.n_components_}")
print(f"Explained variance ratio: {pca.explained_variance_ratio_.sum()}")
# Out:
# Number of components retained: 15
# Explained variance ratio: 0.967904801845848

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(pca_data)

cleaned_data['Cluster'] = clusters

if pca_data.shape[1] >= 2:
    plt.figure(figsize=(10, 7))
    sns.scatterplot(x=pca_data[:, 0], y=pca_data[:, 1], hue=clusters, palette='viridis')
    plt.title("Clusters after PCA")
    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.show()

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=[f"PC{i+1}" for i in range(pca.n_components_)])
print("Cluster Centroids (in PCA space):")
print(centroids)
# Out:
# Cluster Centroids (in PCA space):
#         PC1       PC2        PC3        PC4       PC5       PC6       PC7  \
# 0  1.600097 -0.391229   0.061941  -0.202035  0.112231  0.111700  0.023878
# 1 -1.161920 -4.582744  42.294644  10.831013 -2.571394  2.257088 -1.717014
# 2 -0.994221  0.248596  -0.086383   0.113448 -0.066918 -0.072050 -0.012914
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0  0.077372  0.038733 -0.294813 -0.010334 -0.165500 -0.060867 -0.007454
# 1 -3.360475  4.418415  2.048599 -1.474761  0.106799 -1.125787 -1.898391
# 2 -0.044337 -0.029097  0.181107  0.008098  0.102849  0.039143  0.006785
#
#        PC15
# 0 -0.031324
# 1  4.317140
# 2  0.014605

# %%
original_data_with_clusters = cleaned_data.copy()
original_data_with_clusters['Cluster'] = clusters

centroids_original_space = scaler.inverse_transform(pca.inverse_transform(kmeans.cluster_centers_))
centroids_original_df = pd.DataFrame(centroids_original_space, columns=selected_columns)

risk_mapping = {
    0: "High Risk",
    1: "Medium Risk",
    2: "Low Risk"
}

original_data_with_clusters['Risk Level'] = original_data_with_clusters['Cluster'].map(risk_mapping)

high_risk_companies = original_data_with_clusters[original_data_with_clusters['Risk Level'] == "High Risk"]
medium_risk_companies = original_data_with_clusters[original_data_with_clusters['Risk Level'] == "Medium Risk"]
low_risk_companies = original_data_with_clusters[original_data_with_clusters['Risk Level'] == "Low Risk"]

print("High-Risk Companies:")
print(high_risk_companies)

print("\nMedium-Risk Companies:")
print(medium_risk_companies)

print("\nLow-Risk Companies:")
print(low_risk_companies)
# Out:
# High-Risk Companies:
#         Z-SCORE  Asset liability ratio  Current ratio  Cash ratio  \
# 1      3.844693               0.564089       0.011256    0.438026
# 2      4.975553               0.383526       0.017362    1.015669
# 3      4.088897               0.497172       0.016252    0.519451
# 4     14.464241               0.703506       0.009386    0.690661
# 5     17.191040               0.227639       0.015631    0.734044
# ...         ...                    ...            ...         ...
# 1401  43.762300               0.120000       0.040000    1.000000
# 1410   3.598300               0.530000       0.040000    2.050000
# 1427  18.236300               0.230000       0.020000    0.800000
# 1431   7.772200               0.240000       0.020000    0.300000
# 1436   7.103800               0.170000       0.050000    1.820000
#
#       EBITDA/interest bearing debt       ROA       ROE  \
# 1                         0.326339  0.121959  0.190550
# 2                         0.667316  0.015570  0.034949
# 3                         1.222764  0.164398  0.295278
# 4                         0.745376  0.229710  0.598016
# 5                         5.277343  0.193932  0.183931
# ...                            ...       ...       ...
# 1401                      0.000000  0.030000  0.040000
# 1410                      0.200000  0.090000  0.140000
# 1427                     13.600000  0.120000  0.130000
# 1431                      1.130000  0.130000  0.110000
# 1436                      0.000000  0.060000  0.060000
#
#       Gross profit margin on sales  Net business cycle (days)  \
# 1                         0.727484                   140.8045
# 2                         0.614608                   103.6719
# 3                         0.326878                   116.6440
# 4                         0.592294                   -17.2788
# 5                         0.316779                    37.6660
# ...                            ...                        ...
# 1401                      0.330000                    78.7900
# 1410                      0.550000                    50.9200
# 1427                      0.340000                    71.7100
# 1431                      0.840000                   -26.4500
# 1436                      0.460000                   298.1200
#
#       Turnover rate of accounts receivable (Times)  \
# 1                                           3.5295
# 2                                           7.4687
# 3                                           3.6095
# 4                                         925.2419
# 5                                          68.3220
# ...                                            ...
# 1401                                        4.6900
# 1410                                        3.5300
# 1427                                       30.6000
# 1431                                        4.2700
# 1436                                        1.8300
#
#       Inventory turnover rate (Times)  Stock Volatility  Debt financing costs  \
# 1                              2.3282         48.390237              0.026496
# 2                              2.9242         46.639579              0.018959
# 3                              3.9412         31.025124             -0.001030
# 4                              0.0000         41.572718              0.042445
# 5                              5.2300         46.644312              0.005237
# ...                               ...               ...                   ...
# 1401                           5.3500         53.154900             -0.094422
# 1410                           6.2700         57.170500              0.014774
# 1427                           3.5300         46.715600             -0.000854
# 1431                           0.0000         22.935900              0.003471
# 1436                           1.8300         35.971500             -0.031525
#
#       Share pledge ratio of controlling shareholders   P/E ratio  P/B ratio  \
# 1                                           0.608351   30.422921   5.460896
# 2                                           0.499388  106.732585   3.636306
# 3                                           0.000000   12.819830   3.392250
# 4                                           0.332566   94.022181  65.671415
# 5                                           0.000000   42.785594   7.391967
# ...                                              ...         ...        ...
# 1401                                        0.998800  282.703000   9.350000
# 1410                                        0.582300   43.463000   5.150000
# 1427                                        0.181500   63.228700   8.610000
# 1431                                        0.997800   27.715700   2.780000
# 1436                                        0.366300   27.066900   1.770000
#
#       Stock price rise and fall in the last year  \
# 1                                      -0.133857
# 2                                      -0.304963
# 3                                       0.906496
# 4                                       0.986821
# 5                                      -0.098736
# ...                                          ...
# 1401                                   -0.617200
# 1410                                    0.292100
# 1427                                   -0.355300
# 1431                                   -0.185000
# 1436                                   -0.135400
#
#       Company nature (state owned assets 0, others 1)  Cluster Risk Level
# 1                                                   1        0  High Risk
# 2                                                   1        0  High Risk
# 3                                                   1        0  High Risk
# 4                                                   1        0  High Risk
# 5                                                   1        0  High Risk
# ...                                               ...      ...        ...
# 1401                                                1        0  High Risk
# 1410                                                1        0  High Risk
# 1427                                                1        0  High Risk
# 1431                                                1        0  High Risk
# 1436                                                1        0  High Risk
#
# [549 rows x 20 columns]
#
# Medium-Risk Companies:
#        Z-SCORE  Asset liability ratio  Current ratio  Cash ratio  \
# 1142  2.798711               0.435331        0.01201     0.77998
#
#       EBITDA/interest bearing debt       ROA       ROE  \
# 1142                      0.066496 -0.001315 -0.001286
#
#       Gross profit margin on sales  Net business cycle (days)  \
# 1142                      0.765595                     4198.6
#
#       Turnover rate of accounts receivable (Times)  \
# 1142                                        0.3237
#
#       Inventory turnover rate (Times)  Stock Volatility  Debt financing costs  \
# 1142                            0.101         75.712916              0.000893
#
#       Share pledge ratio of controlling shareholders    P/E ratio  \
# 1142                                             0.0 -5617.788578
#
#         P/B ratio  Stock price rise and fall in the last year  \
# 1142  1329.872846                                    2.590123
#
#       Company nature (state owned assets 0, others 1)  Cluster   Risk Level
# 1142                                                0        1  Medium Risk
#
# Low-Risk Companies:
#         Z-SCORE  Asset liability ratio  Current ratio  Cash ratio  \
# 0      2.420039               0.648161       0.011240    0.394846
# 9      3.250555               0.473534       0.018666    0.901602
# 12     6.580227               0.489388       0.012360    0.542824
# 14     2.020820               0.564368       0.008871    0.358787
# 20     2.768444               0.633090       0.011762    0.181972
# ...         ...                    ...            ...         ...
# 1437   2.060600               0.650000       0.010000    0.300000
# 1438   1.593100               0.580000       0.020000    0.000000
# 1439   4.175800               0.450000       0.010000    0.570000
# 1440  15.781100               0.340000       0.020000    0.240000
# 1441   2.759900               0.850000       0.010000    0.080000
#
#       EBITDA/interest bearing debt       ROA       ROE  \
# 0                         0.501851  0.046191  0.129841
# 9                         0.676477  0.127784  0.196764
# 12                        0.759866  0.106725  0.148207
# 14                        0.293536  0.089340  0.149396
# 20                        0.346021  0.082087  0.165814
# ...                            ...       ...       ...
# 1437                      0.170000  0.040000  0.090000
# 1438                      0.100000  0.040000  0.020000
# 1439                      0.150000  0.030000  0.050000
# 1440                      0.860000  0.060000  0.080000
# 1441                      0.100000  0.020000  0.060000
#
#       Gross profit margin on sales  Net business cycle (days)  \
# 0                         0.193685                   -33.0698
# 9                         0.274844                    48.7665
# 12                        0.163500                    -2.0056
# 14                        0.289639                   -97.0692
# 20                        0.294227                   255.0943
# ...                            ...                        ...
# 1437                      0.370000                   117.6600
# 1438                      0.770000                 11315.3700
# 1439                      0.310000                    56.7100
# 1440                      0.410000                   381.0500
# 1441                      0.060000                    26.7600
#
#       Turnover rate of accounts receivable (Times)  \
# 0                                          22.8269
# 9                                           5.7536
# 12                                         10.6589
# 14                                          3.1247
# 20                                          1.5725
# ...                                            ...
# 1437                                        6.1600
# 1438                                        0.8300
# 1439                                        3.8800
# 1440                                        0.6900
# 1441                                        6.6700
#
#       Inventory turnover rate (Times)  Stock Volatility  Debt financing costs  \
# 0                              6.0945         49.318786             -0.020707
# 9                              6.0864         34.892262              0.011233
# 12                           137.8673         43.330360              0.015672
# 14                            11.4023         36.113156              0.014109
# 20                             2.2524         33.372333              0.026693
# ...                               ...               ...                   ...
# 1437                           3.5900         74.819300              0.045743
# 1438                           0.0300         79.732600              0.051777
# 1439                           0.0000         50.533400              0.021709
# 1440                           6.3600         66.668300              0.013716
# 1441                          10.5400         34.637500              0.011320
#
#       Share pledge ratio of controlling shareholders   P/E ratio  P/B ratio  \
# 0                                           0.152395   31.406188   3.658663
# 9                                           0.641065   17.279174   2.780912
# 12                                          0.318291   54.874477   7.639385
# 14                                          0.521596   21.730218   3.353646
# 20                                          0.716813   37.704037   5.905564
# ...                                              ...         ...        ...
# 1437                                        1.000000   47.170900   3.960000
# 1438                                        1.000000  113.699800   1.820000
# 1439                                        0.920500   80.590900   3.900000
# 1440                                        0.999100  168.083500  12.510000
# 1441                                        1.000000   21.588500   1.390000
#
#       Stock price rise and fall in the last year  \
# 0                                      -0.366077
# 9                                      -0.058550
# 12                                      1.243022
# 14                                     -0.008283
# 20                                      0.298231
# ...                                          ...
# 1437                                   -0.093700
# 1438                                    0.406900
# 1439                                    0.244900
# 1440                                    0.247800
# 1441                                   -0.317600
#
#       Company nature (state owned assets 0, others 1)  Cluster Risk Level
# 0                                                   1        2   Low Risk
# 9                                                   1        2   Low Risk
# 12                                                  1        2   Low Risk
# 14                                                  0        2   Low Risk
# 20                                                  0        2   Low Risk
# ...                                               ...      ...        ...
# 1437                                                1        2   Low Risk
# 1438                                                1        2   Low Risk
# 1439                                                1        2   Low Risk
# 1440                                                1        2   Low Risk
# 1441                                                1        2   Low Risk
#
# [885 rows x 20 columns]
